# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import os
simp_path = '.env'
abs_path = os.path.abspath(simp_path)
CREDENTIAL={'EMAIL':'','PASSWORD':''}
with open(abs_path,"r") as archivo:
    for linea in archivo:        
        if (str(linea.strip('\n')).split('='))[0] == "EMAIL":
            CREDENTIAL["EMAIL"]=(str(linea.strip('\n')).split('='))[1]
        if (str(linea.strip('\n')).split('='))[0] == "PASSWORD":
            CREDENTIAL["PASSWORD"]=(str(linea.strip('\n')).split('='))[1]
            
            
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#abrir formulario

driver.get('https://sivireno.undc.edu.pe/index_login.php')
driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/form/div[1]/a').click()
driver.find_element(by=By.XPATH, value='//*[@id="identifierId"]').send_keys(CREDENTIAL["EMAIL"])
driver.find_element(by=By.XPATH, value='//*[@id="identifierNext"]/div/button/span').click()
for j in range(10):
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="password"]/div[1]/div/div[1]/input').send_keys(CREDENTIAL["PASSWORD"])
        driver.find_element(by=By.XPATH, value='//*[@id="passwordNext"]/div/button/span').click()
        break
    except:
        time.sleep(1)

# %%
#SCRIPT CARGA DET LECTIVA DE MANERA MASIVA
import pandas as pd
import datetime
df = pd.read_excel('EXCEL_TRABAJADO/2024-1cl.xlsx')
df
semanas_xpath= {'1':'//*[@id="exampleFormControlSelect1"]/option[1]',
               '2':'//*[@id="exampleFormControlSelect1"]/option[2]',
               '3':'//*[@id="exampleFormControlSelect1"]/option[3]',
               '4':'//*[@id="exampleFormControlSelect1"]/option[4]',
               '5':'//*[@id="exampleFormControlSelect1"]/option[5]',
               '6':'//*[@id="exampleFormControlSelect1"]/option[6]',
               '7':'//*[@id="exampleFormControlSelect1"]/option[7]',
               '8':'//*[@id="exampleFormControlSelect1"]/option[8]',
               '9':'//*[@id="exampleFormControlSelect1"]/option[9]',
               '10':'//*[@id="exampleFormControlSelect1"]/option[10]',
               '11':'//*[@id="exampleFormControlSelect1"]/option[11]',
               '12':'//*[@id="exampleFormControlSelect1"]/option[12]',
               '13':'//*[@id="exampleFormControlSelect1"]/option[13]',
               '14':'//*[@id="exampleFormControlSelect1"]/option[14]',
               '15':'//*[@id="exampleFormControlSelect1"]/option[15]',
               '16':'//*[@id="exampleFormControlSelect1"]/option[16]',
               '17':'//*[@id="exampleFormControlSelect1"]/option[17]',}

#INICIO DE CLASES
w_iclass={'LUNES':'25/03/2024',
               'MARTES':'26/03/2024',
               'MIERCOLES':'27/03/2024',
               'JUEVES':'28/03/2024',
               'VIERNES':'29/03/2024',
               'SABADO':'30/03/2024',
               'DOMINGO':'31/03/2024'}

urltemp=""
############################################            METODOS
    #ALGORITMO PARA LA FECHA
def convertDateWrite(fecha):
    f = str(fecha).split('-')
    año = f[0]
    mes = f[1]
    d= f[2].split()
    dia = d[0]
    return dia+mes+año
    
    #ALGORTIMO HORA
def convertHourWrite(hour):
    h = str(hour).split(':')
    return h[0]+h[1]

    # 7 + W, CON RESPECTO AL DIA
def sumWeek(dia,sem):
    return convertDateWrite(datetime.datetime.strptime(w_iclass[dia], '%d/%m/%Y')+(datetime.timedelta(days=7)*(sem-1)))

def writeForm(semi,semf,dia,doc,horae,horas,asig,turno,ciclo):
    x=1
    for j in range(int(semi),int(semf+1)):
        print(str(x)+") Asig: "+asig+" "+ciclo+" "+turno+" Docente :"+doc+" SEM:"+str(j)+" semi:"+str(semi)+" semf:"+str(semf)+" FECHA:"+sumWeek(dia,j))
        time.sleep(0.140)
        #ingresar semana
        driver.find_element(by=By.XPATH, value=semanas_xpath[str(int(j))]).click()
        time.sleep(0.150)
        #ingresar fecha
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[2]/input').send_keys(sumWeek(dia,j))

        #ingresar fecha entrada
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[3]/input').send_keys(str(convertHourWrite(horae)))
        #print(str(convertHourWrite(horae)))
        #ingresar fecha salida
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[4]/input').send_keys(str(convertHourWrite(horas)))

        #enviar registro
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[9]/button').click()
        time.sleep(0.100)
        x=x+1
        
############################################            METODOS/*

for row, datos in df.iterrows():
    if datos['FLAG'] == 'SI':
        url = datos['URL']
        semi = datos['SEM_I']
        semf = datos['SEM_F']
        dia = datos['DIA']
        doc=datos['DOCENTE']
        horae = datos['HORAE']
        horas = datos['HORAS']
        asig=datos['ASIGNATURA']
        turno=datos['TURNO']
        ciclo=datos['CICLO']
        if urltemp==url:
            writeForm(semi,semf,dia,doc,horae,horas,asig,turno,ciclo)
            print("")
        else:
            if str(semi)!="nan":   
                urltemp=url
                time.sleep(2)
                driver.get(url)
                time.sleep(1.5)
                writeForm(semi,semf,dia,doc,horae,horas,asig,turno,ciclo)
                print("")
# Out:
# 1) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:8 semi:8.0 semf:17.0 FECHA:16052024
# 2) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:9 semi:8.0 semf:17.0 FECHA:23052024
# 3) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:10 semi:8.0 semf:17.0 FECHA:30052024
# 4) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:11 semi:8.0 semf:17.0 FECHA:06062024
# 5) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:12 semi:8.0 semf:17.0 FECHA:13062024
# 6) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:13 semi:8.0 semf:17.0 FECHA:20062024
# 7) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:14 semi:8.0 semf:17.0 FECHA:27062024
# 8) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:15 semi:8.0 semf:17.0 FECHA:04072024
# 9) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:16 semi:8.0 semf:17.0 FECHA:11072024
# 10) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:17 semi:8.0 semf:17.0 FECHA:18072024
#
# 1) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:7 semi:7.0 semf:17.0 FECHA:08052024
# 2) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:8 semi:7.0 semf:17.0 FECHA:15052024
# 3) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:9 semi:7.0 semf:17.0 FECHA:22052024
# 4) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:10 semi:7.0 semf:17.0 FECHA:29052024
# 5) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:11 semi:7.0 semf:17.0 FECHA:05062024
# 6) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:12 semi:7.0 semf:17.0 FECHA:12062024
# 7) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:13 semi:7.0 semf:17.0 FECHA:19062024
# 8) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:14 semi:7.0 semf:17.0 FECHA:26062024
# 9) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:15 semi:7.0 semf:17.0 FECHA:03072024
# 10) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:16 semi:7.0 semf:17.0 FECHA:10072024
# 11) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:17 semi:7.0 semf:17.0 FECHA:17072024
#
# 1) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:1 semi:1.0 semf:17.0 FECHA:29032024
# 2) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:2 semi:1.0 semf:17.0 FECHA:05042024
# 3) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:3 semi:1.0 semf:17.0 FECHA:12042024
# 4) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:4 semi:1.0 semf:17.0 FECHA:19042024
# 5) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:5 semi:1.0 semf:17.0 FECHA:26042024
# 6) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:6 semi:1.0 semf:17.0 FECHA:03052024
# 7) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:7 semi:1.0 semf:17.0 FECHA:10052024
# 8) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:8 semi:1.0 semf:17.0 FECHA:17052024
# 9) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:9 semi:1.0 semf:17.0 FECHA:24052024
# 10) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:10 semi:1.0 semf:17.0 FECHA:31052024
# 11) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:11 semi:1.0 semf:17.0 FECHA:07062024
# 12) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:12 semi:1.0 semf:17.0 FECHA:14062024
# 13) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:13 semi:1.0 semf:17.0 FECHA:21062024
# 14) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:14 semi:1.0 semf:17.0 FECHA:28062024
# 15) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:15 semi:1.0 semf:17.0 FECHA:05072024
# 16) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:16 semi:1.0 semf:17.0 FECHA:12072024
# 17) Asig: THEG240101 - 1157 - COMUNICACIÓN I T Docente :LEVANO TASAYCO ABEL ALEJANDRO SEM:17 semi:1.0 semf:17.0 FECHA:19072024
#
# 1) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:7 semi:7.0 semf:17.0 FECHA:09052024
# 2) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:8 semi:7.0 semf:17.0 FECHA:16052024
# 3) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:9 semi:7.0 semf:17.0 FECHA:23052024
# 4) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:10 semi:7.0 semf:17.0 FECHA:30052024
# 5) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:11 semi:7.0 semf:17.0 FECHA:06062024
# 6) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:12 semi:7.0 semf:17.0 FECHA:13062024
# 7) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:13 semi:7.0 semf:17.0 FECHA:20062024
# 8) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:14 semi:7.0 semf:17.0 FECHA:27062024
# 9) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:15 semi:7.0 semf:17.0 FECHA:04072024
# 10) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:16 semi:7.0 semf:17.0 FECHA:11072024
# 11) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III M Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:17 semi:7.0 semf:17.0 FECHA:18072024
#
# 1) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:7 semi:7.0 semf:17.0 FECHA:09052024
# 2) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:8 semi:7.0 semf:17.0 FECHA:16052024
# 3) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:9 semi:7.0 semf:17.0 FECHA:23052024
# 4) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:10 semi:7.0 semf:17.0 FECHA:30052024
# 5) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:11 semi:7.0 semf:17.0 FECHA:06062024
# 6) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:12 semi:7.0 semf:17.0 FECHA:13062024
# 7) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:13 semi:7.0 semf:17.0 FECHA:20062024
# 8) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:14 semi:7.0 semf:17.0 FECHA:27062024
# 9) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:15 semi:7.0 semf:17.0 FECHA:04072024
# 10) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:16 semi:7.0 semf:17.0 FECHA:11072024
# 11) Asig: THEG240308 - 1169 - FILOSOFÍA Y ÉTICA III T Docente :PAZ Y MIñO CONDE MANUEL ABRAHAM SEM:17 semi:7.0 semf:17.0 FECHA:18072024

# %%
##SCRIPT PARA CARGA LECTIVA

import pandas as pd
df = pd.read_excel('cargalectiva.xlsx')
df
semanas_xpath= {'1':'//*[@id="exampleFormControlSelect1"]/option[1]',
               '2':'//*[@id="exampleFormControlSelect1"]/option[2]',
               '3':'//*[@id="exampleFormControlSelect1"]/option[3]',
               '4':'//*[@id="exampleFormControlSelect1"]/option[4]',
               '5':'//*[@id="exampleFormControlSelect1"]/option[5]',
               '6':'//*[@id="exampleFormControlSelect1"]/option[6]',
               '7':'//*[@id="exampleFormControlSelect1"]/option[7]',
               '8':'//*[@id="exampleFormControlSelect1"]/option[8]',
               '9':'//*[@id="exampleFormControlSelect1"]/option[9]',
               '10':'//*[@id="exampleFormControlSelect1"]/option[10]',
               '11':'//*[@id="exampleFormControlSelect1"]/option[11]',
               '12':'//*[@id="exampleFormControlSelect1"]/option[12]',
               '13':'//*[@id="exampleFormControlSelect1"]/option[13]',
               '14':'//*[@id="exampleFormControlSelect1"]/option[14]',
               '15':'//*[@id="exampleFormControlSelect1"]/option[15]',
               '16':'//*[@id="exampleFormControlSelect1"]/option[16]'}

try:
    for row, datos in df.iterrows():
        semana = datos['SEMANA']
        fecha = datos['FECHA']
        horae = datos['HORAE']
        horas = datos['HORAS']
        meet = datos['MEET']

        #ALGORITMO PARA LA FECHA
        f = str(fecha).split('-')
        año = f[0]
        mes = f[1]
        d= f[2].split()
        dia = d[0]
        fecha_resolve=[dia+mes+año]

        #ALGORTIMO HORA
        h1 = str(horae).split(':')
        horae=[h1[0]+h1[1]]
        h2 = str(horas).split(':')
        horas=[h2[0]+h2[1]]


        #ingresar semana
        driver.find_element(by=By.XPATH, value=semanas_xpath[str(int(semana))]).click()
        
        #ingresar fecha
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[2]/input').send_keys(fecha_resolve)
        
        #ingresar fecha entrada
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[3]/input').send_keys(str(horae))
        
        #ingresar fecha salida
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[4]/input').send_keys(str(horas))
        
        #ingresar meet
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[5]/input').clear()
        
        if  "nan" == str(meet) :
            print(str(""))
        else:
            driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[5]/input').send_keys(str(meet))
        
        
        #enviar registro
        driver.find_element(by=By.XPATH, value='//*[@id="asistencia_docentes"]/div[4]/div[2]/table/tbody/tr[2]/td[7]/button').click()
        time.sleep(0.200)
except:
    print("error")

# %%
##SCRIPT EXTRAER TODOS LOS LINK DE CARGA LECTIVA Y NO LECTIVA
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
import time
asig = []
ciclo = []
t = []
s = []
c = []
docen = []
cl = []
cnl = []
av=[]
sila=[]
baseURL="https://sivireno.undc.edu.pe/"
##la cantidad que te muestra el sivireno
cantlist=100

###########################################CREACION DE METODOS#################################################################

def addLinkExcel():
    df = pd.DataFrame({ 'ASIGNATURA': asig,'CICLO': ciclo,'TURNO': t,'SECCION': s,'CANT': c,'DOCENTE': docen,'CL': cl,'CNL': cnl,'AV':av,'SILABUS':sila})
    df = df[['ASIGNATURA', 'CICLO','TURNO','SECCION','CANT','DOCENTE','CL','CNL','AV','SILABUS']]
    writer = pd.ExcelWriter('EXCEL_GENERADOS/CREATE_LIST_CURSOS_AGRONOMIA'+time.strftime("%Y%m%d-%H-%M-%S")+'.xlsx')
    df.to_excel(writer, 'Sheet', index=False)
    #writer.save()
    writer.close()
    print("TERMINO PROCESO")
###########################################CREACION DE METODOS#################################################################
try:
    for j in range(int(cantlist)):
        
        #SOLO PARA LA MODALIDAD DEL CURSO EN M
                                                    
        if driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[3]').text =="M":
            asig.append(driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[4]').text)
            ciclo.append(driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[5]').text)
            t.append(driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[6]').text)
            s.append(driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[7]').text)
            c.append(driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[8]').text)
            docen.append(driver.find_element(by=By.XPATH, value='//*[@id="app"]/div[2]/table/tbody/tr['+str(j+1)+']/td[9]').text)
            cl.append(baseURL+driver.execute_script('return document.querySelector("#app > div.table-responsive > table > tbody > tr:nth-child('+str(j+1)+') > td:nth-child(10) > a:nth-child(1)").getAttribute("href");'))
            cnl.append(baseURL+driver.execute_script('return document.querySelector("#app > div.table-responsive > table > tbody > tr:nth-child('+str(j+1)+') > td:nth-child(10) > a:nth-child(2)").getAttribute("href");'))
            av.append(driver.execute_script('return document.querySelector("#app > div.table-responsive > table > tbody > tr:nth-child('+str(j+1)+') > td:nth-child(13) > a").getAttribute("href");'))
            sila.append(driver.execute_script('return document.querySelector("#app > div.table-responsive > table > tbody > tr:nth-child('+str(j+1)+') > td:nth-child(11) > a").getAttribute("href");'))
    addLinkExcel()
except:
    addLinkExcel()
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[2], line 47
#      46         av.append(driver.execute_script('return document.querySelector("#app > div.table-responsive > table > tbody > tr:nth-child('+str(j+1)+') > td:nth-child(13) > a").getAttribute("href");'))
# ---> 47         sila.append(driver.execute_script('return document.querySelector("#app > div.table-responsive > table > tbody > tr:nth-child('+str(j+1)+') > td:nth-child(11) > a").getAttribute("href");'))
#      49 addLinkExcel()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:407, in WebDriver.execute_script(self, script, *args)
#     405 command = Command.W3C_EXECUTE_SCRIPT
# --> 407 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# JavascriptException: Message: javascript error: Cannot read properties of null (reading 'getAttribute')
#   (Session info: chrome=124.0.6367.119)
# Stacktrace:
# 	GetHandleVerifier [0x009EC113+48259]
# 	(No symbol) [0x0097CA41]
# 	(No symbol) [0x00870A17]
# 	(No symbol) [0x00875B58]
# 	(No symbol) [0x008778CA]
# 	(No symbol) [0x008EA505]
# 	(No symbol) [0x008D0D9C]
# 	(No symbol) [0x008E9B9C]
# 	(No symbol) [0x008D0B36]
# 	(No symbol) [0x008A570D]
# 	(No symbol) [0x008A62CD]
# 	GetHandleVerifier [0x00CA65A3+2908435]
# 	GetHandleVerifier [0x00CE3BBB+3159851]
# 	GetHandleVerifier [0x00A850CB+674875]
# 	GetHandleVerifier [0x00A8B28C+699900]
# 	(No symbol) [0x00986244]
# 	(No symbol) [0x00982298]
# 	(No symbol) [0x0098242C]
# 	(No symbol) [0x00974BB0]
# 	BaseThreadInitThunk [0x764C5D49+25]
# 	RtlInitializeExceptionChain [0x777DCEBB+107]
# 	RtlGetAppContainerNamedObjectPath [0x777DCE41+561]
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 51
#      49     addLinkExcel()
#      50 except:
# ---> 51     addLinkExcel()
#
# Cell In[2], line 24, in addLinkExcel()
#      23 def addLinkExcel():
# ---> 24     df = pd.DataFrame({ 'ASIGNATURA': asig,'CICLO': ciclo,'TURNO': t,'SECCION': s,'CANT': c,'DOCENTE': docen,'CL': cl,'CNL': cnl,'AV':av,'SILABUS':sila})
#      25     df = df[['ASIGNATURA', 'CICLO','TURNO','SECCION','CANT','DOCENTE','CL','CNL','AV','SILABUS']]
#      26     writer = pd.ExcelWriter('EXCEL_GENERADOS/CREATE_LIST_CURSOS_AGRONOMIA'+time.strftime("%Y%m%d-%H-%M-%S")+'.xlsx')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
import os
simp_path = '.env'
abs_path = os.path.abspath(simp_path)
CREDENTIAL={'EMAIL':'','PASSWORD':''}
with open(abs_path,"r") as archivo:
    for linea in archivo:        
        if (str(linea.strip('\n')).split('='))[0] == "EMAIL":
            CREDENTIAL["EMAIL"]=(str(linea.strip('\n')).split('='))[1]
        if (str(linea.strip('\n')).split('='))[0] == "PASSWORD":
            CREDENTIAL["PASSWORD"]=(str(linea.strip('\n')).split('='))[1]
