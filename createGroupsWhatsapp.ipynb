# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)

#abrir formulario
time.sleep(2.5)
url="https://web.whatsapp.com/"
driver.get(url)

# %%
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
import time
#DELETE

# %%
# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
##TENER WHATSAPP BUSSINESS

import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
import time
linkwsp = []
namegroup = []
#Excel donde se trabaja el semestre academico
df = pd.read_excel('EXCEL_TRABAJADO/2023-2.xlsx')
#Usuario a quien vamos a necesitar para realizar el grupo
nameCollaboratorWsp = "José Angulo Soporte Agronomía"
###########################################CREACION DE METODOS#################################################################
def createGroup(namegroups):    
    #Click crear chat
    driver.find_element(by=By.XPATH, value='//*[@data-icon="chat"]').click()
    time.sleep(0.5)
    #click crear Grupo    
    driver.find_element(by=By.XPATH, value='//*[@title="Nuevo grupo"]').click()
    time.sleep(0.5)
    #Escribir nombre del colaborador para el grupo
    driver.find_element(by=By.XPATH, value='//*[@placeholder="Escribe el nombre del contacto"]').send_keys(nameCollaboratorWsp)
    time.sleep(1)
    #Dar click en el unico resultado
    driver.find_element(by=By.XPATH, value='//*[@role="gridcell"]').click()
    time.sleep(1)
    #dar boton siguiente
    driver.find_element(by=By.XPATH, value='//*[@data-icon="arrow-forward"]').click()
    time.sleep(1)
    #escribir nombre de grupo
    driver.find_element(by=By.XPATH, value='//*[@title="Asunto del grupo (opcional)"]').send_keys(str(namegroups))
    time.sleep(1)
    #click confirmar creacion de gruo
    driver.find_element(by=By.XPATH, value='//*[@data-icon="checkmark-medium"]').click()
    time.sleep(2.5)
    # click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header').click()
    time.sleep(1.0)
    #Click Enlace de invitacion
    driver.find_element(by=By.XPATH, value='//*[@data-icon="link"]').click()
    time.sleep(2)
    #obtener link del enlace
    getLinkWSP = driver.find_element(by=By.XPATH, value='//*[@id="group-invite-link-anchor"]')    
    linkwsp.append(getLinkWSP.text)
    namegroup.append(namegroups)
    time.sleep(1.000)
    #Click retroceder 
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/header/div/div[1]/div/span').click()
    time.sleep(1.000)
    ### Eliminar miembro
    
    #deleteMember()
    
    ### Si el miembro, apoya a la carrera, tambien debe ser admin
    addAdminMember()
    
    
def deleteMember():
    try:
        #mouse hover
        ele =driver.find_element(by=By.XPATH, value='//*[@style="z-index: 0; transition: none 0s ease 0s; height: 68px; transform: translateY(68px);"]')
        ActionChains(driver).move_to_element(ele).perform()
        #Da clic en la flechita para desplegar
        driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/div[6]/span/div/span/div/div/div/section//*[@aria-label="Abrir el menú contextual del chat"]').click()
        time.sleep(0.400)
        #da click en eliminar
        driver.find_element(by=By.XPATH, value='//*[@aria-label="Eliminar"]').click()
        time.sleep(0.800)
        #da click en confirmar la eliminacion
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/button[2]/div/div').click()
        time.sleep(0.700)
    except:
        print("ERROR AL ELIMINAR")

def addAdminMember():
    #mouse hover
    ele =driver.find_element(by=By.XPATH, value='//*[@style="z-index: 0; transition: none 0s ease 0s; height: 68px; transform: translateY(68px);"]')
    ActionChains(driver).move_to_element(ele).perform()
    #Da clic en la flechita para desplegar
    driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/div[6]/span/div/span/div/div/div/section//*[@aria-label="Abrir el menú contextual del chat"]').click()
    time.sleep(0.400)
    #da click en eliminar
    driver.find_element(by=By.XPATH, value='//*[@aria-label="Designar como admin. del grupo"]').click()
    time.sleep(0.800)
    #da click en confirmar la eliminacion
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/button[2]/div/div').click()
    time.sleep(0.700)
        
def addLinkExcel():
    df = pd.DataFrame({ 'NAME_GROUP_WSP': namegroup,'LINK_GROUP_wSP': linkwsp})
    df = df[['NAME_GROUP_WSP', 'LINK_GROUP_wSP']]
    writer = pd.ExcelWriter('EXCEL_GENERADOS/LINKWSP'+time.strftime("%Y%m%d-%H-%M-%S")+'.xlsx')
    df.to_excel(writer, 'Sheet', index=False)
    #writer.save()
    writer.close()
###########################################CREACION DE METODOS#################################################################
try:
    for row, datos in df.iterrows():
        if datos['FLAG']=='SI':
            #nombre de la columna
            namewsp = datos['NOMBRE_DE_GRUPO']
            print("1")
            print(namewsp)
            time.sleep(2)
            print("2")
            #da click del primer resultaldo, si son varios resultados por lo general el resultado es del maximo hacia arriba
            #si hay 6 resultados, la fila del resultado a dar clic seria el 6
            print("3")
            createGroup(namewsp)
            print("4")
            time.sleep(0.8)
        else:    
        #####AL TERMINAR DE AGREGAR TODOS LOS LINK CREAMOS NUESTRO EXCEL CON LOS ARRAYS OBTENIDOS
            s=""
    addLinkExcel()
except:
    addLinkExcel()
# Out:
# 1
# AG_X-M-A FORMULACIÓN Y EV
# 2
# 3
# 4
# 1
# AG_X-T-B FORMULACIÓN Y EV
# 2
# 3
# 4

# %%
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/header/div/div[1]/div/span').click()

# %%
##EJECUTANDO CREACION CON OTRO NUMERO QUE NO PERTENCE A LA CARRERA
# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
import time
linkwsp = []
namegroup = []
cantCreateGroups=100
df = pd.read_excel('EXCEL_TRABAJADO/2023-1.xlsx')
nameCollaboratorWsp = "AGianmarcos NT"
###########################################CREACION DE METODOS#################################################################
def deleteGroup():
    #da click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
    time.sleep(1.000)
    #Dar click salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
    time.sleep(0.8)
    #confimar salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div').click()
    time.sleep(1.8)
    #Eliminar grupo
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    except:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    #Confirmar la eliminacion del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
    time.sleep(2.000)
    
def createGroup(namegroups):
    print("CreateGroup")
    #Click crear chat
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[4]/header/div[2]/div/span/div[3]/div/span').click()
    time.sleep(0.5)
    #click crear Grupo    
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/div[1]/span/div/span/div/div[2]/div[1]/div/div/div[2]/div/div').click()
    time.sleep(0.5)
    #Escribir nombre del colaborador para el grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/div[1]/span/div/span/div/div/div[1]/div/div/div[2]/input').send_keys(nameCollaboratorWsp)
    time.sleep(1)
    #Dar click en el unico resultado
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/div[1]/span/div/span/div/div/div[2]/div/div/div/div/div/div/div[2]/div[1]/div/span').click()
    time.sleep(1)
    #dar boton siguiente
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/div[1]/span/div/span/div/div/span/div/span').click()
    time.sleep(1)
    #escribir nombre de grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/div[1]/span/div/span/div/div/div[1]/div[2]/div/div[2]/div[1]/div/div[2]').send_keys(str(namegroups))
    time.sleep(1)
    #click confirmar creacion de gruo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/div[1]/span/div/span/div/div/span/div/div').click()
    time.sleep(2.5)
    # click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
    time.sleep(1.0)
    #Click Enlace de invitacion
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[2]/div[2]/div[2]/div/div').click()
    time.sleep(2)
    #obtener link del enlace
    getLinkWSP = driver.find_element(by=By.XPATH, value='//*[@id="group-invite-link-anchor"]')
    linkwsp.append(getLinkWSP.text)
    namegroup.append(namegroups)
    
    #Click retroceder 
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/header/div/div[1]/div/span').click()
    time.sleep(2)
    try:
        #mouse hover
        ele =driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[1]/div/span')    
        ActionChains(driver).move_to_element(ele).perform()
        time.sleep(1)
        #abrir lista de acciones a realizar al usuario
        try:
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[2]/button/span').click()
        except:
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[2]/button/span').click()
        time.sleep(0.800)

        #da click en agregar como administrador
        ll = driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div')
        if ll.text=="Descartar como admin.":
            print("")
        else:
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div').click()
        time.sleep(1.00)
        #da click en confirmar la designar administrador
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/div[2]/div/div').click()
        time.sleep(1.300)
        deleteGroup()
    except:
        print('')
def addLinkExcel():
    df = pd.DataFrame({ 'NAME_GROUP_WSP': namegroup,'LINK_GROUP_wSP': linkwsp})
    df = df[['NAME_GROUP_WSP', 'LINK_GROUP_wSP']]
    writer = pd.ExcelWriter('EXCEL_GENERADOS/LINKWSP'+time.strftime("%Y%m%d-%H-%M-%S")+'.xlsx')
    df.to_excel(writer, 'Sheet', index=False)
    #writer.save()
    writer.close()
###########################################CREACION DE METODOS#################################################################
try:
    for row, datos in df.iterrows():
        if datos['FLAG']=='SI':
            #nombre de la columna
            namewsp = datos['NOMBRE_DE_GRUPO']
            time.sleep(2)
            #da click del primer resultaldo, si son varios resultados por lo general el resultado es del maximo hacia arriba
            #si hay 6 resultados, la fila del resultado a dar clic seria el 6
            if(cantCreateGroups > row ):
                createGroup(namewsp)
                time.sleep(0.8)
        else:    
        #####AL TERMINAR DE AGREGAR TODOS LOS LINK CREAMOS NUESTRO EXCEL CON LOS ARRAYS OBTENIDOS
            s=""
    addLinkExcel()
except:
    addLinkExcel()

# %%
#da click en el nombre del grupo
driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
time.sleep(1.000)
#Dar click salir grupo
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
time.sleep(0.8)
#confimar salir grupo
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div').click()
time.sleep(1.8)
#Eliminar grupo
try:
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
    time.sleep(1.5)
except:
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[6]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
    time.sleep(1.5)
#Confirmar la eliminacion del grupo
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
time.sleep(2.000)

# %%
##ELIMINAR GRUPO

# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
df = pd.read_excel('grupowsp.xlsx')
#nombre de la columna

def deleteGroup():
    time.sleep(1.500)
    #Dar click salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
    time.sleep(1.2)
    #confimar salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div/div').click()
    time.sleep(1.3)
    #Eliminar grupo
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[5]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    except:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    #Confirmar la eliminacion del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
    time.sleep(2.000)
for row, datos in df.iterrows():
    namewsp = datos['NOMBRE_DE_GRUPO']
    time.sleep(2)
    #buscador de Chat (persona/grupo)
    driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div[2]').clear()
    time.sleep(1)
    driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div[2]').send_keys(namewsp)
    time.sleep(0.5)
    for j in range(int(11)):
        try:
            #8 RESULTADO ADICIONAL
            driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']').click()
            time.sleep(1)
            #da click en el nombre del grupo
            driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
            time.sleep(1)
            deleteGroup()
        except NoSuchElementException:
            print('siguiente')                      
    time.sleep(0.8)

# %%
##ELIMINAR GRUPO

# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
df = pd.read_excel('EXCEL_TRABAJADO/2023-2.xlsx')
#nombre de la columna

def addAdminMember():
    #mouse hover
    ele =driver.find_element(by=By.XPATH, value='//*[@style="z-index: 0; transition: none 0s ease 0s; height: 68px; transform: translateY(68px);"]')
    ActionChains(driver).move_to_element(ele).perform()
    #Da clic en la flechita para desplegar
    driver.find_element(by=By.XPATH, value='/html/body/div[1]/div/div/div[6]/span/div/span/div/div/div/section//*[@aria-label="Abrir el menú contextual del chat"]').click()
    time.sleep(0.400)
    #da click en eliminar
    driver.find_element(by=By.XPATH, value='//*[@aria-label="Designar como admin. del grupo"]').click()
    time.sleep(0.800)
    #da click en confirmar la eliminacion
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/button[2]/div/div').click()
    time.sleep(0.700)
    
for row, datos in df.iterrows():
    if datos['FLAG'] == 'SI':
        namewsp = datos['NOMBRE_DE_GRUPO']
        time.sleep(2)
        #buscador de Chat (persona/grupo)
        try:
            driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/span/button').click()
        except:
            s="error"
        time.sleep(1)
        driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div').send_keys(namewsp)
        time.sleep(0.5)
        for j in range(int(11)):
            try:
                #8 RESULTADO ADICIONAL
                #da click en el nombre del grupo
                if driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']/div/div/div/div[2]/div[1]/div[1]/span/span').text == namewsp:
                    driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']').click()
                    time.sleep(1)
                    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
                    time.sleep(1)
                    addAdminMember()
            except NoSuchElementException:
                print('siguiente')                      
        time.sleep(0.8)
# Out:
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# ...
