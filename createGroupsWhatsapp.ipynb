# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#abrir formulario
time.sleep(2.5)
url="https://web.whatsapp.com/"
driver.get(url)

# %%
# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
import time
linkwsp = []
namegroup = []
cantCreateGroups=20
df = pd.read_excel('EXCEL_TRABAJADO/2023-0.xlsx')
nameCollaboratorWsp = "Gianmarcos New"
###########################################CREACION DE METODOS#################################################################
def deleteGroup():
    #da click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
    time.sleep(1.000)
    #Dar click salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
    time.sleep(0.8)
    #confimar salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div/div').click()
    time.sleep(1.8)
    #Eliminar grupo
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[5]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    except:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    #Confirmar la eliminacion del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
    time.sleep(2.000)
    
def createGroup(namegroups):
    print("CreateGroup")
    #Click crear chat
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/header/div[2]/div/span/div[2]/div/span').click()
    time.sleep(0.5)
    #click crear Grupo    
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div[2]/div[1]/div/div[1]/div[2]/div/div').click()
    time.sleep(0.5)
    #Escribir nombre del colaborador para el grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/div[1]/div/div/input').send_keys(nameCollaboratorWsp)
    time.sleep(1)
    #Dar click en el unico resultado
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/div[2]/div/div/div/div/div/div/div[2]/div[1]/div/span').click()
    time.sleep(1)
    #dar boton siguiente
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/span/div/span').click()
    time.sleep(1)
    #escribir nombre de grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/div[1]/div[2]/div/div[2]/div[1]/div/div[2]').send_keys(str(namegroups))
    time.sleep(1)
    #click confirmar creacion de gruo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/span/div/div/span').click()
    time.sleep(2.5)
    # click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
    time.sleep(1.0)
    #Click Enlace de invitacion
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[2]').click()
    time.sleep(2)
    #obtener link del enlace
    getLinkWSP = driver.find_element(by=By.XPATH, value='//*[@id="group-invite-link-anchor"]')
    
    linkwsp.append(getLinkWSP.text)
    namegroup.append(namegroups)
    
    #Click retroceder 
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/header/div/div[1]/div/span').click()
    try:
        for j in range(int(11)):
            #print("entra al primer for "+str(j+1))
            #mouse hover
            time.sleep(2)
            ele =driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]')                                                                
            ActionChains(driver).move_to_element(ele).perform()
            #Da clic en la flechita para desplegar
            try:
                ##cuando no tienen nombre o descripcion
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[2]/button').click()
            except:
                ##cuando no tienen nombre o descripcion
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[3]/button').click()
            time.sleep(0.400)
            #da click en eliminar
            ll=driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div')
            if ll.text=="Descartar como admin.":
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div').click()
            else:
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
            time.sleep(0.800)
            #da click en confirmar la eliminacion
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/div[2]/div/div').click()
            time.sleep(1.000)
    except:
        s=""
def addLinkExcel():
    df = pd.DataFrame({ 'NAME_GROUP_WSP': namegroup,'LINK_GROUP_wSP': linkwsp})
    df = df[['NAME_GROUP_WSP', 'LINK_GROUP_wSP']]
    writer = pd.ExcelWriter('EXCEL_GENERADOS/LINKWSP'+time.strftime("%Y%m%d-%H-%M-%S")+'.xlsx')
    df.to_excel(writer, 'Sheet', index=False)
    #writer.save()
    writer.close()
###########################################CREACION DE METODOS#################################################################
try:
    for row, datos in df.iterrows():
        #nombre de la columna
        namewsp = datos['NOMBRE_DE_GRUPO']
        time.sleep(2)
        #da click del primer resultaldo, si son varios resultados por lo general el resultado es del maximo hacia arriba
        #si hay 6 resultados, la fila del resultado a dar clic seria el 6
        if(cantCreateGroups > row ):
            if datos['FLAG']=='SI':
                createGroup(namewsp)
                time.sleep(0.8)
        else:    
        #####AL TERMINAR DE AGREGAR TODOS LOS LINK CREAMOS NUESTRO EXCEL CON LOS ARRAYS OBTENIDOS
            print('')
    addLinkExcel()
except:
    addLinkExcel()
# Out:
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup

# %%
driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
time.sleep(1.0)
#Click Enlace de invitacion
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[2]').click()
time.sleep(2)
#obtener link del enlace
getLinkWSP = driver.find_element(by=By.XPATH, value='//*[@id="group-invite-link-anchor"]')

# %%
##EJECUTANDO CREACION CON OTRO NUMERO QUE NO PERTENCE A LA CARRERA
# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
import time
linkwsp = []
namegroup = []
cantCreateGroups=25
df = pd.read_excel('grupowsp.xlsx')
nameCollaboratorWsp = "Miguel Vera Soporte Sistemas Undc"
###########################################CREACION DE METODOS#################################################################
def deleteGroup():
    #da click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
    time.sleep(1.000)
    #Dar click salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
    time.sleep(0.8)
    #confimar salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div/div').click()
    time.sleep(1.8)
    #Eliminar grupo
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[5]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    except:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    #Confirmar la eliminacion del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
    time.sleep(2.000)
    
def createGroup(namegroups):
    print("CreateGroup")
    #Click crear chat
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[3]/header/div[2]/div/span/div[3]/div/span').click()
    time.sleep(0.5)
    #click crear Grupo    
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div[2]/div[1]/div/div[1]/div[2]/div/div').click()
    time.sleep(0.5)
    #Escribir nombre del colaborador para el grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/div[1]/div/div/input').send_keys(nameCollaboratorWsp)
    time.sleep(1)
    #Dar click en el unico resultado
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/div[2]/div/div/div/div/div/div/div[2]/div[1]/div/span').click()
    time.sleep(1)
    #dar boton siguiente
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/span/div/span').click()
    time.sleep(1)
    #escribir nombre de grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/div[1]/div[2]/div/div[2]/div[1]/div/div[2]').send_keys(str(namegroups))
    time.sleep(1)
    #click confirmar creacion de gruo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[1]/span/div/span/div/div/span/div/div/span').click()
    time.sleep(2.5)
    # click en el nombre del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
    time.sleep(1.0)
    #Click Enlace de invitacion
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[2]/div[2]/div/div').click()
    time.sleep(2)
    #obtener link del enlace
    getLinkWSP = driver.find_element(by=By.XPATH, value='//*[@id="group-invite-link-anchor"]')
    linkwsp.append(getLinkWSP.text)
    namegroup.append(namegroups)
    
    #Click retroceder 
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/header/div/div[1]/button/span').click()
    time.sleep(2)
    try:
        #mouse hover
        ele =driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[1]/div/div/div[2]/div[1]/div/span')    
        ActionChains(driver).move_to_element(ele).perform()
        time.sleep(1)
        #abrir lista de acciones a realizar al usuario
        try:
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[1]/div/div/div[2]/div[2]/div[2]/span[2]').click()
        except:
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[1]/div/div/div[2]/div[2]/div[2]/span[3]').click()
        time.sleep(0.800)

        #da click en agregar como administrador
        ll = driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div[1]')
        if ll.text=="Descartar como admin.":
            print("")
        else:
            driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div[1]').click()
        time.sleep(1.00)
        #da click en confirmar la eliminacion
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/div[2]/div/div').click()
        time.sleep(1.300)
    except:
        print('')
def addLinkExcel():
    df = pd.DataFrame({ 'NAME_GROUP_WSP': namegroup,'LINK_GROUP_wSP': linkwsp})
    df = df[['EXCEL_GENERADOS/NAME_GROUP_WSP', 'LINK_GROUP_wSP']]
    writer = pd.ExcelWriter('LINKWSP'+time.strftime("%Y%m%d-%H-%M-%S")+'.xlsx')
    df.to_excel(writer, 'Sheet', index=False)
    #writer.save()
    writer.close()
###########################################CREACION DE METODOS#################################################################
try:
    for row, datos in df.iterrows():
        #nombre de la columna
        namewsp = datos['NOMBRE_DE_GRUPO']
        time.sleep(2)
        #da click del primer resultaldo, si son varios resultados por lo general el resultado es del maximo hacia arriba
        #si hay 6 resultados, la fila del resultado a dar clic seria el 6
        createGroup(namewsp)
        time.sleep(0.8)
        if (row+1) >=cantCreateGroups:
            addLinkExcel()
            break
    addLinkExcel()
except:
    addLinkExcel()
# Out:
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
# CreateGroup
#
#
# CreateGroup
#
#
# CreateGroup
#
# CreateGroup

# %%
##ELIMINAR GRUPO

# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
df = pd.read_excel('grupowsp.xlsx')
#nombre de la columna

def deleteGroup():
    time.sleep(1.500)
    #Dar click salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
    time.sleep(1.2)
    #confimar salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div/div').click()
    time.sleep(1.3)
    #Eliminar grupo
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[5]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    except:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    #Confirmar la eliminacion del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
    time.sleep(2.000)
for row, datos in df.iterrows():
    namewsp = datos['NOMBRE_DE_GRUPO']
    time.sleep(2)
    #buscador de Chat (persona/grupo)
    driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div[2]').clear()
    time.sleep(1)
    driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div[2]').send_keys(namewsp)
    time.sleep(0.5)
    for j in range(int(11)):
        try:
            #8 RESULTADO ADICIONAL
            driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']').click()
            time.sleep(1)
            #da click en el nombre del grupo
            driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
            time.sleep(1)
            deleteGroup()
        except NoSuchElementException:
            print('siguiente')                      
    time.sleep(0.8)
# Out:
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente

# %%
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/header/div/div[1]/button/span').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17736\1509899772.py in <module>
# ----> 1 driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/header/div/div[1]/button/span').click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     831
#     832     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="app"]/div/div/div[2]/div[3]/span/div/span/div/header/div/div[1]/button/span"}
#   (Session info: chrome=109.0.5414.74)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00D66643]
# 	(No symbol) [0x00CFBE21]
# 	(No symbol) [0x00BFDA9D]
# 	(No symbol) [0x00C31342]
# 	(No symbol) [0x00C3147B]
# 	(No symbol) [0x00C68DC2]
# 	(No symbol) [0x00C4FDC4]
# 	(No symbol) [0x00C66B09]
# 	(No symbol) [0x00C4FB76]
# 	(No symbol) [0x00C249C1]
# 	(No symbol) [0x00C25E5D]
# 	GetHandleVerifier [0x00FDA142+2497106]
# 	GetHandleVerifier [0x010085D3+2686691]
# 	GetHandleVerifier [0x0100BB9C+2700460]
# 	GetHandleVerifier [0x00E13B10+635936]
# 	(No symbol) [0x00D04A1F]
# 	(No symbol) [0x00D0A418]
# 	(No symbol) [0x00D0A505]
# 	(No symbol) [0x00D1508B]
# 	BaseThreadInitThunk [0x75F800F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77007BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77007B8E+238]
