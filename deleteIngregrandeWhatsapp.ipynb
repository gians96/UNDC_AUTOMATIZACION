# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager


service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)


#abrir formulario
time.sleep(2.5)
url="https://web.whatsapp.com/"
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18892\3578967542.py in <module>
#      15 time.sleep(2.5)
#      16 url="https://web.whatsapp.com/"
# ---> 17 driver.get(url)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     447
#     448     def close(self) -> None:
# --> 449         """Closes the current window.
#     450
#     451         :Usage:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438     def page_source(self) -> str:
#     439         """Gets the source of the current page.
# --> 440
#     441         :Usage:
#     442             ::
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#
# ...

# %%
##SCRIPT PARA ELIMINAR PARTICIPANTES DE UN GRUPO

# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
df = pd.read_excel('grupowsp.xlsx')
#nombre de la columna
    
characters = "'!?() "
namecourse = ''
#######################################################
def deleteIntegrante():
    try:
        #Quita todos las letras espacios, o caracteres especiales.
        dd=driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[1]/div/div[3]/span/span/button')
        cant= re.sub(r'[a-zA-Z-áú]','',dd.text).rstrip()
        for x in range(len(characters)):
            cant = cant.replace(characters[x],'')
        cant = int(cant)
        cant = cant-1
        #Si es mayor a 10 se genera otro tipo de script
        print(namecourse+' '+dd.text)
        if int(cant) >10:
            for j in range(int(cant)):
                #print("entra al primer for "+str(j+1))
                #hover mouse encima del utlimo participante para mostrar la flecha para el despliegue
                ele =driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]')
                ActionChains(driver).move_to_element(ele).perform()
                #Da clic en la flechita para desplegar
                try:
                    ##cuando no tienen nombre o descripcion
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[2]/button').click()
                except:
                    ##cuando no tienen nombre o descripcion
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[3]/button').click()
                time.sleep(0.400)
                #da click en eliminar
                ll=driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div')
                if ll.text=="Descartar como admin.":
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
                if ll.text=="Eliminar":
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div').click()
                else:
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
                time.sleep(0.800)
                #da click en confirmar la eliminacion
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/div[2]/div/div').click()
                time.sleep(1.000)
            
        for j in range(11):
            if (11-j) != 10:
                #print("entra al segundo for "+str(11-j))
                #mouse hover
                ele =driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div['+str(11-j)+']')
                ActionChains(driver).move_to_element(ele).perform()
                time.sleep(0.5)
                #Da clic en la flechita para desplegar
                ##cuando no tienen nombre o descripcion
                try:
                    ##cuando no tienen nombre o descripcion
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[2]/button').click()
                except:
                    ##cuando no tienen nombre o descripcion
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[3]/button').click()
                time.sleep(0.400)
                #da click en eliminar
                ll=driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div')
                if ll.text=="Descartar como admin.":
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
                if ll.text=="Eliminar":
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div').click()
                else:
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
                time.sleep(0.800)
                #da click en confirmar la eliminacion
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/div[2]/div/div').click()
                time.sleep(1.000)
    #Cuando es menor <= 11
    except NoSuchElementException:
        try:
            for j in range(int(11)):
                #print("entra al tercer for "+str(j+1))
                #mouse hover
                ele =driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]')    
                ActionChains(driver).move_to_element(ele).perform()
                time.sleep(0.500)
                #abrir lista de acciones a realizar al usuario
                try:
                    ##cuando no tienen nombre o descripcion
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[2]/button').click()
                except:
                    ##cuando no tienen nombre o descripcion
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[2]/div[3]/div/div[2]/div/div/div[2]/div[2]/div[2]/span[3]/button').click()
                time.sleep(0.400)
                #da click en eliminar
                ll=driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div')
                if ll.text=="Descartar como admin.":
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
                if ll.text=="Eliminar":
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[1]/div').click()
                else:
                    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[4]/div/ul/div/li[2]/div').click()
                time.sleep(0.800)
                #da click en confirmar la eliminacion
                driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[2]/div/div[2]/div/div').click()
                time.sleep(1.000)
        except:
            s="error"
            

    #######################################################

for row, datos in df.iterrows():
    namewsp = datos['NOMBRE_DE_GRUPO']
    namecourse =datos['NOMBRE_DE_GRUPO']
    #buscador de Chat (persona/grupo)
    #driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div').clear() #ANTES
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/span/button').click()
    except:
        s="error"
    time.sleep(1)
    driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div').send_keys(namewsp)
    time.sleep(1)
    #da click del primer resultaldo
    for j in range(int(11)):
        try:
            #8 RESULTADO ADICIONAL
            #da click en el nombre del grupo            
            if driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']/div/div/div/div[2]/div[1]/div[1]/span/span').text == namewsp:
                #Click en el resultado que se parezca
                driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']').click()
                time.sleep(1)
                #Click en la parte superior del nombre para ver los integrantes
                driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
                time.sleep(1)
                deleteIntegrante()
        except:
            s="error"
# Out:
# AG_I-M-A BIOLOGÍA GENERAL 2 participantes
# AG_I-T-B CIUDADANÍA - 286 1 participante
# AG_III-T-B FÍSICA I - 287 1 participante
# AG_IV-M-A ESTADÍSTICA GEN 1 participante
# AG_IV-M-A MICROECONOMÍA - 1 participante
# AG_IV-T-B ANÁLISIS MATEMÁ 1 participante
# AG_IV-T-B ANÁLISIS MATEMÁ 1 participante
# AG_IV-T-B ANÁLISIS MATEMÁ 1 participante
# AG_IV-T-B FÍSICA - 2871 1 participante
# AG_VII-M-A MEJORAMIENTO G 1 participante
# AG_VII-M-A HIDROLOGÍA Y S 1 participante
# AG_VII-M-A CEREALES Y PSE 2 participantes

# %%
##ELIMINAR GRUPO

# import pandas as pd
#NOTA: antes de ejecutar el script, copiar la imagen en clipboard.(click derecho copiar, o ctrl+c)
#nombre del excel que contiene los nombres de los grupos de whatsapp
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import re
from selenium.common.exceptions import NoSuchElementException
df = pd.read_excel('grupowsp.xlsx')
#nombre de la columna

def deleteGroup():
    time.sleep(1.500)
    #Dar click salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
    time.sleep(1.2)
    #¿Deseas Salir del Grupo? confimar salir grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[3]/div/div').click()
    time.sleep(1.3)
    #Eliminar grupo
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[5]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    except:
        driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[6]/div[1]/div[2]/div/span').click()
        time.sleep(1.5)
    #Cambios en el vacios o eliminacion de los chats: -> Confirmar la eliminacion del grupo
    driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/span[2]/div/div/div/div/div/div/div[3]/div/div[2]/div/div').click()
    time.sleep(2.000)
for row, datos in df.iterrows():
    namewsp = datos['NOMBRE_DE_GRUPO']
    time.sleep(2)
    #buscador de Chat (persona/grupo)
    try:
        driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/span/button').click()
    except:
        s="error"
    time.sleep(1)
    driver.find_element(by=By.XPATH, value='//*[@id="side"]/div[1]/div/div/div[2]/div/div').send_keys(namewsp)
    time.sleep(0.5)
    for j in range(int(11)):
        try:
            #8 RESULTADO ADICIONAL
            #da click en el nombre del grupo
            if driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']/div/div/div/div[2]/div[1]/div[1]/span/span').text == namewsp:
                driver.find_element(by=By.XPATH, value='//*[@id="pane-side"]/div[1]/div/div/div['+str(11-j)+']').click()
                time.sleep(1)
                driver.find_element(by=By.XPATH, value='//*[@id="main"]/header/div[2]/div[1]/div/span').click()
                time.sleep(1)
                deleteGroup()
        except NoSuchElementException:
            print('siguiente')                      
    time.sleep(0.8)
# Out:
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# siguiente
# ...

# %%
driver.find_element(by=By.XPATH, value='//*[@id="app"]/div/div/div[5]/span/div/span/div/div/section/div[7]/div[1]/div[2]/div/span').click()
